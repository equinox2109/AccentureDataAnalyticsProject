# %%
import numpy as np
import pandas as pd
# Out:
# C:\Users\Jay\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
data_rxn = pd.read_csv("Reactions.csv",delimiter=',')
data_rxn
# Out:
#        Unnamed: 0                            Content ID  \
# 0               0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...           ...                                   ...
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550       25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type             Datetime
# 0                                       NaN         NaN  2021-04-22 15:17:15
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# ...

# %%
df_rxn=data_rxn.copy()

# %%
df_rxn.columns.values
# Out:
# array(['Unnamed: 0', 'Content ID', 'User ID', 'Type', 'Datetime'],
#       dtype=object)

# %% [markdown]
# ###  Drop First and Date columns

# %%
df_rxn=df_rxn.drop(["Datetime","Unnamed: 0"],axis=1)

# %%
df_rxn
# Out:
#                                  Content ID  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type
# 0                                       NaN         NaN
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike
# 3      163daa38-8b77-48c9-9af6-37a6c1447ac2      scared
# 4      34e8add9-0206-47fd-a501-037b994650a2     disgust
# ...                                     ...         ...
# ...

# %%
df_rxn["User ID"].isna().sum()
# Out:
# 3019

# %%
df_rxn.shape
# Out:
# (25553, 3)

# %%
df_rxn["Type"].isna().sum()
# Out:
# 980

# %%
df_rxn["Type"].unique()
# Out:
# array([nan, 'disgust', 'dislike', 'scared', 'interested', 'peeking',
#        'cherish', 'hate', 'love', 'indifferent', 'super love',
#        'intrigued', 'worried', 'like', 'heart', 'want', 'adore'],
#       dtype=object)

# %% [markdown]
# ###  Replace Null with 0 in user_id column

# %%
temp = df_rxn.copy()

# %%
temp["User ID"].fillna(0,inplace=True)

# %%
temp["User ID"].isna().sum()
# Out:
# 0

# %% [markdown]
# ###  Drop rows where reaction type is null

# %%
temp["Type"].dropna(inplace=True)

# %%
temp.dropna(inplace=True)

# %%
temp.shape
# Out:
# (24573, 3)

# %%
temp.isna().sum()
# Out:
# Content ID    0
# User ID       0
# Type          0
# dtype: int64

# %%
df_rxn_clean = temp

# %%
df_rxn_clean
# Out:
#                                  Content ID  \
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 5      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike
# 3      163daa38-8b77-48c9-9af6-37a6c1447ac2      scared
# 4      34e8add9-0206-47fd-a501-037b994650a2     disgust
# 5      9b6d35f9-5e15-4cd0-a8d7-b1f3340e02c4  interested
# ...                                     ...         ...
# ...

# %% [markdown]
# #  Cleaning Content Table

# %%
raw_con = pd.read_csv("Content.csv", delimiter =',')
raw_con
# Out:
#      Unnamed: 0                            Content ID  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180
# ..          ...                                   ...
# 995         995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category  \
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# ...

# %%
df_con.isna().sum()
# Out:
# Unnamed: 0      0
# Content ID      0
# User ID         0
# Type            0
# Category        0
# URL           199
# dtype: int64

# %% [markdown]
# ### Drop 1st, Type and URL column

# %%
df_con.columns.values
# Out:
# array(['Unnamed: 0', 'Content ID', 'User ID', 'Type', 'Category', 'URL'],
#       dtype=object)

# %%
df_con=df_con.drop(["Unnamed: 0", "Type", "URL"],axis=1)

# %%
df_con_clean = df_con.copy()
df_con_clean
# Out:
#                                Content ID  \
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3    356fff80-da4d-4785-9f43-bc1261031dc6
# 4    01ab84dd-6364-4236-abbb-3f237db77180
# ..                                    ...
# 995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID         Category
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4   healthy eating
# 3    9fb4ce88-fac1-406c-8544-1a899cee7aaf       technology
# 4    e206e31b-5f85-4964-b6ea-d7ee5324def1             food
# ..                                    ...              ...
# ...

# %% [markdown]
# #  ReactionType table

# %%
data_rxn_type = pd.read_csv("ReactionTypes.csv")
data_rxn_type
# Out:
#     Unnamed: 0         Type Sentiment  Score
# 0            0        heart  positive     60
# 1            1         want  positive     70
# 2            2      disgust  negative      0
# 3            3         hate  negative      5
# 4            4   interested  positive     30
# 5            5  indifferent   neutral     20
# 6            6         love  positive     65
# 7            7   super love  positive     75
# 8            8      cherish  positive     70
# 9            9        adore  positive     72
# 10          10         like  positive     50
# 11          11      dislike  negative     10
# 12          12    intrigued  positive     45
# 13          13      peeking   neutral     35
# 14          14       scared  negative     15
# 15          15      worried  negative     12

# %%
df_rxn_type = data_rxn_type.copy()

# %% [markdown]
# ### Drop 1st and Sentiment column

# %%
df_rxn_type=df_rxn_type.drop(["Unnamed: 0","Sentiment"],axis=1)

# %%
df_rxn_type_clean = df_rxn_type.copy()
df_rxn_type_clean
# Out:
#            Type  Score
# 0         heart     60
# 1          want     70
# 2       disgust      0
# 3          hate      5
# 4    interested     30
# 5   indifferent     20
# 6          love     65
# 7    super love     75
# 8       cherish     70
# 9         adore     72
# 10         like     50
# 11      dislike     10
# 12    intrigued     45
# 13      peeking     35
# 14       scared     15
# 15      worried     12

# %%
df_rxn_type_clean.to_csv("rxn_type_clean.csv")
df_rxn_clean.to_csv("rxn_clean.csv")
df_con_clean.to_csv("content_clean.csv")

# %% [markdown]
# # Merging the dataframes

# %%
# rxn_clean = pd.read_csv("Reactions-clean.csv")
con_clean = pd.read_csv("Content-clean.csv")

# %%
rxn_clean.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
con_clean.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
con_clean
# Out:
#                                Content ID   Type         Category
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2  photo         Studying
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810  photo   healthy eating
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f  photo   healthy eating
# 3    356fff80-da4d-4785-9f43-bc1261031dc6  photo       technology
# 4    01ab84dd-6364-4236-abbb-3f237db77180  video             food
# ..                                    ...    ...              ...
# 995  b4cef9ef-627b-41d7-a051-5961b0204ebb  video  public speaking
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c    GIF       technology
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b  audio         veganism
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    GIF          culture
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56  audio       technology
#
# [1000 rows x 3 columns]

# %%
rxn_clean
# Out:
#        Unnamed: 0                            Content ID        Type  \
# 0               1  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# 1               2  97522e57-d9ab-4bd6-97bf-c24d952602d2     dislike
# 2               3  97522e57-d9ab-4bd6-97bf-c24d952602d2      scared
# 3               4  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# 4               5  97522e57-d9ab-4bd6-97bf-c24d952602d2  interested
# ...           ...                                   ...         ...
# 24568       25548  75d6b589-7fae-4a6d-b0d0-752845150e56     dislike
# 24569       25549  75d6b589-7fae-4a6d-b0d0-752845150e56   intrigued
# 24570       25550  75d6b589-7fae-4a6d-b0d0-752845150e56  interested
# 24571       25551  75d6b589-7fae-4a6d-b0d0-752845150e56     worried
# 24572       25552  75d6b589-7fae-4a6d-b0d0-752845150e56     cherish
#
#                Datetime
# 0      07-11-2020 09:43
# 1      17-06-2021 12:22
# 2      18-04-2021 05:13
# 3      06-01-2021 19:13
# ...

# %%
df_merge_1 = pd.merge(rxn_clean,con_clean, how='inner', on=['Content ID'])

# %%
df_merge_1
# Out:
#        Unnamed: 0                            Content ID Reaction Type  \
# 0               1  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 1               2  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 2               3  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared
# 3               4  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 4               5  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested
# ...           ...                                   ...           ...
# 24568       25548  75d6b589-7fae-4a6d-b0d0-752845150e56       dislike
# 24569       25549  75d6b589-7fae-4a6d-b0d0-752845150e56     intrigued
# 24570       25550  75d6b589-7fae-4a6d-b0d0-752845150e56    interested
# 24571       25551  75d6b589-7fae-4a6d-b0d0-752845150e56       worried
# 24572       25552  75d6b589-7fae-4a6d-b0d0-752845150e56       cherish
#
#                Datetime Content Type    Category
# 0      07-11-2020 09:43        photo    Studying
# ...

# %%
df_merge_1.columns = ['Unnamed: 0', 'Content ID', 'Reaction Type', 'Datetime', 'Content Type',
       'Category']

# %%
df_merge_1.isna().sum()
# Out:
# Unnamed: 0    0
# Content ID    0
# Type          0
# Datetime      0
# User ID       0
# Category      0
# dtype: int64

# %%
df_rxn_type_clean
# Out:
#    Reaction Type  Score
# 0          heart     60
# 1           want     70
# 2        disgust      0
# 3           hate      5
# 4     interested     30
# 5    indifferent     20
# 6           love     65
# 7     super love     75
# 8        cherish     70
# 9          adore     72
# 10          like     50
# 11       dislike     10
# 12     intrigued     45
# 13       peeking     35
# 14        scared     15
# 15       worried     12

# %%
df_rxn_type_clean.columns = ['Reaction Type', 'Score']

# %%
df_final_merge = pd.merge(df_merge_1,df_rxn_type_clean, how='inner', on=['Reaction Type'])

# %%
df_final_merge
# Out:
#        Unnamed: 0                            Content ID Reaction Type  \
# 0               1  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 1               4  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 2              35  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 3              52  9f737e0a-3cdd-4d29-9d24-753f4e3be810       disgust
# 4              88  230c4e4d-70c3-461d-b42c-ec09396efb3f       disgust
# ...           ...                                   ...           ...
# 24568       25489  435007a5-6261-4d8b-b0a4-55fdc189754b         adore
# 24569       25491  435007a5-6261-4d8b-b0a4-55fdc189754b         adore
# 24570       25512  4e4c9690-c013-4ee7-9e66-943d8cbd27b7         adore
# 24571       25524  4e4c9690-c013-4ee7-9e66-943d8cbd27b7         adore
# 24572       25531  4e4c9690-c013-4ee7-9e66-943d8cbd27b7         adore
#
#                Datetime Content Type        Category  Score
# 0      07-11-2020 09:43        photo        Studying      0
# ...

# %%
df_final_merge.to_csv("Cleaned-Dataset.csv")

# %%
group_by_contentID=df_final_merge.groupby(['Category'])

# %%
group_by_contentID.agg({'Score':sum})
# Out:
#                  Score
# Category
# Animals           3723
# Culture           1627
# Education         1395
# Fitness           5488
# Food              3504
# Healthy Eating     272
# Public Speaking   1336
# Science           4619
# Soccer            2631
# Studying          1341
# Technology         217
# Travel            1092
# Veganism           644
# animals          71242
# cooking          64756
# culture          64952
# dogs             52511
# education        56041
# fitness          49835
# food             63172
# healthy eating   69067
# public speaking  47928
# science          66549
# soccer           55152
# studying         52928
# technology       68521
# tennis           50339
# travel           63788
# veganism         48975
